# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('C:/book.jpg',cv2.IMREAD_COLOR)

# %%
px=img[65,65] #to find the value of color at the specific pixel
print(px)
# Out:
# [156 200 213]

# %%
img[56,56]=[255,255,255]
px1=img[56,56]
print(px1)
# Out:
# [255 255 255]

# %%
img[100:200,100:200]=[255,255,255]
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# plt.imshow(img,cmap='gray',interpolation='bicubic')
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
book_part=img[100:200,200:300]
img[0:100,0:100]=book_part

plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
